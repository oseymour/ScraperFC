# %% [markdown]
# python setup.py sdist bdist_wheel
#
# twine upload --skip-existing dist/*

# %%
import ScraperFC as sfc
import traceback
import pandas as pd
import numpy as np
from urllib.error import HTTPError

# %%
scraper = sfc.FBRef(driver="firefox")
try:
    out = scraper.scrape_league_table(2021, 'EPL')
except:
    traceback.print_exc()
scraper.close()
# Out:
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST driver version for 103.0.5060
# [WDM] - There is no [win32] chromedriver for browser 103.0.5060 in cache
# [WDM] - Get LATEST driver version for 103.0.5060
# [WDM] - Trying to download new driver from https://chromedriver.storage.googleapis.com/103.0.5060.134/chromedriver_win32.zip
# [WDM] - Driver has been saved in cache [C:\Users\Owner\.wdm\drivers\chromedriver\win32\103.0.5060.134]
# Scraping 2021 EPL league table

# %%
out
# Out:
#     Rk            Squad   team_id  MP   W   D   L  GF  GA  GD  Pts  Pts/MP  \
# 0    1  Manchester City  b8fd03ef  38  27   5   6  83  32  51   86    2.26
# 1    2   Manchester Utd  19538871  38  21  11   6  73  44  29   74    1.95
# 2    3        Liverpool  822bd0ba  38  20   9   9  68  42  26   69    1.82
# 3    4          Chelsea  cff3d9bb  38  19  10   9  58  36  22   67    1.76
# 4    5   Leicester City  a2d435b3  38  20   6  12  68  50  18   66    1.74
# 5    6         West Ham  7c21e445  38  19   8  11  62  47  15   65    1.71
# 6    7        Tottenham  361ca564  38  18   8  12  68  45  23   62    1.63
# 7    8          Arsenal  18bb7c10  38  18   7  13  55  39  16   61    1.61
# 8    9     Leeds United  5bfb9659  38  18   5  15  62  54   8   59    1.55
# 9   10          Everton  d3fd31cc  38  17   8  13  47  48  -1   59    1.55
# 10  11      Aston Villa  8602292d  38  16   7  15  55  46   9   55    1.45
# 11  12    Newcastle Utd  b2b47a98  38  12   9  17  46  62 -16   45    1.18
# 12  13           Wolves  8cec06e1  38  12   9  17  36  52 -16   45    1.18
# 13  14   Crystal Palace  47c64c55  38  12   8  18  41  66 -25   44    1.16
# 14  15      Southampton  33c895d4  38  12   7  19  47  68 -21   43    1.13
# 15  16         Brighton  d07537b9  38   9  14  15  40  46  -6   41    1.08
# 16  17          Burnley  943e8050  38  10   9  19  33  55 -22   39    1.03
# 17  18           Fulham  fd962109  38   5  13  20  27  53 -26   28    0.74
# 18  19        West Brom  60c6b05f  38   5  11  22  35  76 -41   26    0.68
# 19  20    Sheffield Utd  1df6b87e  38   7   2  29  20  63 -43   23    0.61
#
#       xG   xGA   xGD  Attendance                     Top Team Scorer  \
# 0   73.3  31.4  42.0         526                 İlkay Gündoğan - 13
# 1   60.2  42.2  18.0         526                Bruno Fernandes - 18
# 2   72.6  45.3  27.3         837                  Mohamed Salah - 22
# 3   64.0  32.8  31.2         526                        Jorginho - 7
# 4   56.0  47.7   8.3         421                    Jamie Vardy - 15
# 5   53.9  48.3   5.6         632  Tomáš Souček, Michail Antonio - 10
# 6   54.5  49.5   5.0         632                     Harry Kane - 23
# 7   53.5  44.3   9.2         632            Alexandre Lacazette - 13
# 8   57.5  62.9  -5.4         421                Patrick Bamford - 17
# 9   47.1  52.0  -4.9         368          Dominic Calvert-Lewin - 16
# 10  52.9  52.9   0.1         526                  Ollie Watkins - 14
# 11  41.0  54.0 -13.0         526                  Callum Wilson - 12
# 12  39.9  45.8  -6.0         237         Rúben Neves, Pedro Neto - 5
# 13  32.4  57.5 -25.0         447                  Wilfried Zaha - 11
# 14  42.4  54.2 -11.8         526                     Danny Ings - 12
# 15  51.6  37.7  13.9         523                     Neal Maupay - 8
# 16  39.9  57.6 -17.7         178                     Chris Wood - 12
# 17  41.3  52.9 -11.7         211                      Bobby Reid - 5
# 18  33.8  67.7 -34.0         283                Matheus Pereira - 11
# 19  31.4  62.4 -31.0         263                David McGoldrick - 8
#
#            Goalkeeper                                           Notes
# 0             Ederson            → Champions League via league finish
# 1        David de Gea            → Champions League via league finish
# 2             Alisson            → Champions League via league finish
# 3       Edouard Mendy            → Champions League via league finish
# 4   Kasper Schmeichel                     → Europa League via cup win
# 5    Łukasz Fabiański               → Europa League via league finish
# 6         Hugo Lloris  → Europa Conference League via league finish 1
# 7          Bernd Leno                                             NaN
# 8       Illan Meslier                                             NaN
# 9     Jordan Pickford                                             NaN
# 10  Emiliano Martínez                                             NaN
# 11        Karl Darlow                                             NaN
# 12       Rui Patrício                                             NaN
# 13     Vicente Guaita                                             NaN
# 14      Alex McCarthy                                             NaN
# 15     Robert Sánchez                                             NaN
# 16          Nick Pope                                             NaN
# 17    Alphonse Areola                                       Relegated
# 18      Sam Johnstone                                       Relegated
# 19     Aaron Ramsdale                                       Relegated

# %%
# scraper = sfc.FBRef()

# packets = [
#     [
#         1993,
#         "https://fbref.com/en/matches/2fc61b31/Liverpool-Tottenham-Hotspur-May-8-1993-Premier-League"
#     ],
#     [
#         2017,
#         "https://fbref.com/en/matches/78c3fc92/Hull-City-Leicester-City-August-13-2016-Premier-League"
#     ],
#     [
#         2018,
#         "https://fbref.com/en/matches/e3c3ddf0/Arsenal-Leicester-City-August-11-2017-Premier-League"
#     ]
# ]

# out = 1
# while out != -1:
#     for packet in packets:
#         try:
#             out = scraper.scrape_match(league="EPL", year=packet[0], link=packet[1])
#             if out is not int:
#                 out = 1
#         except HTTPError as E:
#             traceback.print_exc()
#             print(E.headers)
#             out = -1
#         except IndexError:
#             pass
# scraper.close()
# Out:
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST driver version for 103.0.5060
# [WDM] - Driver [C:\Users\Owner\.wdm\drivers\chromedriver\win32\103.0.5060.53\chromedriver.exe] found in cache
# Traceback (most recent call last):
#   File "<ipython-input-2-836b3f6a9324>", line 22, in <module>
#     out = scraper.scrape_match(league="EPL", year=packet[0], link=packet[1])
#   File "C:\Users\Owner\Documents\GitHub\ScraperFC\code\ScraperFC\FBRef.py", line 839, in scrape_match
#     df = pd.read_html(link)
#   File "C:\Users\Owner\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 299, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Owner\anaconda3\lib\site-packages\pandas\io\html.py", line 1085, in read_html
#     return _parse(
#   File "C:\Users\Owner\anaconda3\lib\site-packages\pandas\io\html.py", line 893, in _parse
#     tables = p.parse_tables()
#   File "C:\Users\Owner\anaconda3\lib\site-packages\pandas\io\html.py", line 213, in parse_tables
#     tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#   File "C:\Users\Owner\anaconda3\lib\site-packages\pandas\io\html.py", line 732, in _build_doc
#     raise e
#   File "C:\Users\Owner\anaconda3\lib\site-packages\pandas\io\html.py", line 713, in _build_doc
#     with urlopen(self.io) as f:
#   File "C:\Users\Owner\anaconda3\lib\site-packages\pandas\io\common.py", line 195, in urlopen
#     return urllib.request.urlopen(*args, **kwargs)
#   File "C:\Users\Owner\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\Owner\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\Owner\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\Owner\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\Owner\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\Owner\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 429: Too Many Requests
# Date: Mon, 18 Jul 2022 03:01:06 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: close
# CF-Chl-Bypass: 1
# Permissions-Policy: accelerometer=(),autoplay=(),camera=(),clipboard-read=(),clipboard-write=(),fullscreen=(),geolocation=(),gyroscope=(),hid=(),interest-cohort=(),magnetometer=(),microphone=(),payment=(),publickey-credentials-get=(),screen-wake-lock=(),serial=(),sync-xhr=(),usb=()
# Cache-Control: private, max-age=0, no-store, no-cache, must-revalidate, post-check=0, pre-check=0
# Expires: Thu, 01 Jan 1970 00:00:01 GMT
# X-Frame-Options: SAMEORIGIN
# Expect-CT: max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"
# Set-Cookie: __cf_bm=ZgfG_X8YZGzb8l_oY9YD.UuDIaoL7JYaCm0Omo9pNdU-1658113266-0-AfKzwYxzKChn1xm1JUSUDEdyLN3pXxD4lsEhbj/bwVQDpyjtIW6SB5kgJtT3iup4pdaDlQjdPzXdIALGj27tOcA=; path=/; expires=Mon, 18-Jul-22 03:31:06 GMT; domain=.fbref.com; HttpOnly; Secure; SameSite=None
# Vary: Accept-Encoding
# Server: cloudflare
# CF-RAY: 72c7f88cac6b86f9-ORD

# %% [markdown]
# python setup.py sdist bdist_wheel
#
# twine upload --skip-existing dist/*

# %%
import ScraperFC as sfc
import traceback
import pandas as pd
import numpy as np

# %%
scraper = sfc.FBRef()
try:
    # link = 'https://fbref.com/en/matches/b7e24dcd/Bologna-Perugia-October-19-2003-Serie-A'
    # match = scraper.scrape_match(link)
    match_links = scraper.get_match_links(2021, 'EPL')
    matches = scraper.scrape_matches(2021, 'EPL')
except:
    traceback.print_exc()
scraper.close()
# Out:
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST driver version for 103.0.5060
# [WDM] - Driver [C:\Users\Owner\.wdm\drivers\chromedriver\win32\103.0.5060.134\chromedriver.exe] found in cache
# Gathering match links.
# 100%|██████████████████████████████████████████████████████████████████████████████| 1900/1900 [00:44<00:00, 42.85it/s]
# Gathering match links.
# 100%|██████████████████████████████████████████████████████████████████████████████| 1900/1900 [01:00<00:00, 31.62it/s]
# Scraping matches.
# 100%|████████████████████████████████████████████████████████████████████████████████| 380/380 [53:08<00:00,  8.39s/it]

# %%
matches.shape[0], len(match_links)
# Out:
# (380, 380)

# %%
matches
# Out:
#                                                   Link        Date Matchweek  \
# 0    https://fbref.com/en/matches/db261cb0/Crystal-...  2020-09-12         1
# 1    https://fbref.com/en/matches/21b58926/Liverpoo...  2020-09-12         1
# 2    https://fbref.com/en/matches/bf52349b/Fulham-A...  2020-09-12         1
# 3    https://fbref.com/en/matches/78495ced/West-Ham...  2020-09-12         1
# 4    https://fbref.com/en/matches/fc7f9aa1/Tottenha...  2020-09-13         1
# ..                                                 ...         ...       ...
# 375  https://fbref.com/en/matches/f966eee0/Fulham-N...  2021-05-23        38
# 376  https://fbref.com/en/matches/2c07a228/Sheffiel...  2021-05-23        38
# 377  https://fbref.com/en/matches/2c081c94/Wolverha...  2021-05-23        38
# 378  https://fbref.com/en/matches/50ec33b2/West-Ham...  2021-05-23        38
# 379  https://fbref.com/en/matches/9ade2b5d/Leeds-Un...  2021-05-23        38
#
#                    Home Team             Away Team Home Team ID Away Team ID  \
# 0             Crystal Palace           Southampton     47c64c55     33c895d4
# 1                  Liverpool          Leeds United     822bd0ba     5bfb9659
# 2                     Fulham               Arsenal     fd962109     18bb7c10
# 3            West Ham United      Newcastle United     7c21e445     b2b47a98
# 4          Tottenham Hotspur               Everton     361ca564     d3fd31cc
# ..                       ...                   ...          ...          ...
# 375                   Fulham      Newcastle United     fd962109     b2b47a98
# 376         Sheffield United               Burnley     1df6b87e     943e8050
# 377  Wolverhampton Wanderers     Manchester United     8cec06e1     19538871
# 378          West Ham United           Southampton     7c21e445     33c895d4
# 379             Leeds United  West Bromwich Albion     5bfb9659     60c6b05f
#
#     Home Formation Away Formation Home Goals  ... Away Ast Home xG Away xG  \
# 0            4-4-2          4-4-2          1  ...        0     0.7     0.8
# 1            4-3-3        4-1-4-1          4  ...        2     3.3     0.6
# 2          4-2-3-1          3-4-3          0  ...        2     0.2     2.0
# 3          4-2-3-1          4-4-2          0  ...        2     1.2     1.5
# 4          4-2-3-1          4-3-3          0  ...        1     1.0     1.4
# ..             ...            ...        ...  ...      ...     ...     ...
# 375          3-4-3          3-5-2          0  ...        0     0.9     1.2
# 376          3-4-3        4-4-1-1          1  ...        0     0.6     1.0
# 377          3-5-2        4-2-3-1          1  ...        1     0.9     1.7
# 378        4-2-3-1          4-4-2          3  ...        0     1.6     1.5
# 379          3-4-3          3-5-2          3  ...        0     2.0     1.7
#
#     Home npxG Away npxG Home xA Away xA  \
# 0         0.7       0.8     0.7     0.6
# 1         1.8       0.6     1.5     0.3
# 2         0.2       2.0     0.1     1.0
# 3         1.2       1.5     1.0     1.4
# 4         1.0       1.4     0.8     0.7
# ..        ...       ...     ...     ...
# 375       0.9       0.4     0.8     0.3
# 376       0.6       1.0     0.4     1.0
# 377       0.9       1.0     0.5     0.9
# 378       1.6       1.5     1.0     1.4
# 379       1.2       1.7     0.8     0.9
#
#                                      Home Player Stats  \
# 0    Team Sheet       Crystal Palace (4-4-2) Crysta...
# 1    Team Sheet       Liverpool (4-3-3)     Liverpo...
# 2    Team Sheet       Fulham (4-2-3-1)          Ful...
# 3    Team Sheet       West Ham (4-2-3-1) West Ham (...
# 4    Team Sheet       Tottenham (4-2-3-1) Tottenham...
# ..                                                 ...
# 375  Team Sheet       Fulham (3-4-3)            Ful...
# 376  Team Sheet       Sheffield Utd (3-4-3) Sheffie...
# 377  Team Sheet       Wolves (3-5-2)     Wolves (3-...
# 378  Team Sheet       West Ham (4-2-3-1) West Ham (...
# 379  Team Sheet       Leeds United (3-4-3) Leeds Un...
#
#                                      Away Player Stats  \
# 0    Team Sheet       Southampton (4-4-2) Southampt...
# 1    Team Sheet       Leeds United (4-1-4-1) Leeds ...
# 2    Team Sheet       Arsenal (3-4-3)          Arse...
# 3    Team Sheet       Newcastle Utd (4-4-2) Newcast...
# 4    Team Sheet       Everton (4-3-3)      Everton ...
# ..                                                 ...
# 375  Team Sheet       Newcastle Utd (3-5-2) Newcast...
# 376  Team Sheet       Burnley (4-4-1-1)       Burnl...
# 377  Team Sheet       Manchester Utd (4-2-3-1) Manc...
# 378  Team Sheet       Southampton (4-4-2) Southampt...
# 379  Team Sheet       West Brom (3-5-2)     West Br...
#
#                                                  Shots
# 0    Both       Unnamed: 0_level_0 Unnamed: 1_level...
# 1    Both       Unnamed: 0_level_0   Unnamed: 1_lev...
# 2    Both       Unnamed: 0_level_0         Unnamed:...
# 3    Both       Unnamed: 0_level_0   Unnamed: 1_lev...
# 4    Both       Unnamed: 0_level_0     Unnamed: 1_l...
# ..                                                 ...
# 375  Both       Unnamed: 0_level_0          Unnamed...
# 376  Both       Unnamed: 0_level_0       Unnamed: 1...
# 377  Both       Unnamed: 0_level_0  Unnamed: 1_leve...
# 378  Both       Unnamed: 0_level_0  Unnamed: 1_leve...
# 379  Both       Unnamed: 0_level_0      Unnamed: 1_...
#
# [380 rows x 22 columns]

# %%
import sys
sys.path.append('..')
import ScraperFC as sfc # import local scraperfc
import traceback
import pandas as pd
import numpy as np

# %%
scraper = sfc.FiveThirtyEight()
try:
    data2018 = scraper.scrape_matches(2018, 'EPL')
    print('2018 done')
    data2019 = scraper.scrape_matches(2019, 'EPL')
    print('2019 done')
except:
    traceback.print_exc()
scraper.close()
# Out:
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 105.0.5195
# [WDM] - Get LATEST driver version for 105.0.5195
# [WDM] - Driver [C:\Users\Owner\.wdm\drivers\chromedriver\win32\105.0.5195.52\chromedriver.exe] found in cache
# 2018 done
# 2019 done

# %%
data2018
# Out:
#     season        date  league_id                   league  \
# 0     2018  2017-08-11       2411  Barclays Premier League
# 1     2018  2017-08-12       2411  Barclays Premier League
# 2     2018  2017-08-12       2411  Barclays Premier League
# 3     2018  2017-08-12       2411  Barclays Premier League
# 4     2018  2017-08-12       2411  Barclays Premier League
# ..     ...         ...        ...                      ...
# 375   2018  2018-05-13       2411  Barclays Premier League
# 376   2018  2018-05-13       2411  Barclays Premier League
# 377   2018  2018-05-13       2411  Barclays Premier League
# 378   2018  2018-05-13       2411  Barclays Premier League
# 379   2018  2018-05-13       2411  Barclays Premier League
#
#                     team1                     team2   spi1   spi2   prob1  \
# 0                 Arsenal            Leicester City  78.18  61.77  0.6430
# 1                 Watford                 Liverpool  54.25  77.15  0.2193
# ...

# %%
data2019
# Out:
#     season        date  league_id                   league              team1  \
# 0     2019  2018-08-10       2411  Barclays Premier League  Manchester United
# 1     2019  2018-08-11       2411  Barclays Premier League          Newcastle
# 2     2019  2018-08-11       2411  Barclays Premier League  Huddersfield Town
# 3     2019  2018-08-11       2411  Barclays Premier League            Watford
# 4     2019  2018-08-11       2411  Barclays Premier League    AFC Bournemouth
# ..     ...         ...        ...                      ...                ...
# 375   2019  2019-05-12       2411  Barclays Premier League        Southampton
# 376   2019  2019-05-12       2411  Barclays Premier League            Burnley
# 377   2019  2019-05-12       2411  Barclays Premier League     Crystal Palace
# 378   2019  2019-05-12       2411  Barclays Premier League     Leicester City
# 379   2019  2019-05-12       2411  Barclays Premier League            Watford
#
# ...

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../src')
import ScraperFC as sfc

# %%
ss = sfc.Sofascore()

# %%
match_id = 12436923
ss.scrape_player_match_stats(match_id)[["name", "id", "teamName", "teamId"]]
# Out:
#                     name       id           teamName  teamId
# 0              Nick Pope   162653   Newcastle United      39
# 1   Valentino Livramento   980634   Newcastle United      39
# 2            Emil Krafth   150396   Newcastle United      39
# 3               Dan Burn    99090   Newcastle United      39
# 4            Lloyd Kelly   865167   Newcastle United      39
# 5         Sean Longstaff   866191   Newcastle United      39
# 6        Bruno Guimarães   866469   Newcastle United      39
# 7              Joelinton   560128   Newcastle United      39
# 8         Anthony Gordon   914902   Newcastle United      39
# 9         Alexander Isak   823941   Newcastle United      39
# 10         Harvey Barnes   855647   Newcastle United      39
# 11          Jacob Murphy   372336   Newcastle United      39
# 12            Lewis Hall  1136730   Newcastle United      39
# 13         Sandro Tonali   892673   Newcastle United      39
# ...
